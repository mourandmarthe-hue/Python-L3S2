# %%
from pyvest.asset import Asset
from pyvest.priceseries import PriceSeries
from pyvest.constant import CurrencyEnum

# %%
test = Asset('aapl', [100])
# Out:
# Traceback (most recent call last):
#   File "/home/marthe/.vscode-server/extensions/ms-python.python-2026.0.0-linux-x64/python_files/python_server.py", line 134, in exec_user_input
#     retval = callable_(user_input, user_globals)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<string>", line 1, in <module>
#   File "/home/marthe/dev/Python-L3S2/pyvest/src/pyvest/asset.py", line 58, in __init__
#     if any(prices < 0):
#            ^^^^^^^^^^
# TypeError: '<' not supported between instances of 'list' and 'int'

# %%
test = Asset('aapl', [100])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 test = Asset('aapl', [100])
#
# NameError: name 'Asset' is not defined

# %%
from pyvest.asset import Asset

test = Asset("aapl", [100])

# %%
from pyvest.asset import Asset
from pyvest.priceseries import PriceSeries
from pyvest.constant import CurrencyEnum

# %%
test = Asset("aapl", [100])

# %%
from pyvest.asset import Asset
from pyvest.priceseries import PriceSeries
from pyvest.constant import CurrencyEnum

# %%
test = Asset("aapl", [100])
